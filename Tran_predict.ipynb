# %% [markdown]
# STOCK TRADING USING TRANSFER MODEL

# %%
# import tensorflow as tf
# import numpy as np
# import csv
# import matplotlib.pyplot as plt

# %%
import data
# Load the data
dates = data.dates
openPrice = data.openPrices
highest = data.highesPrices
lowest = data.lowestPrices
closePrice = data.closePrices
volumes = data.intvolumes
date = data.terms
# visualize the data
plt.plot(date, openPrice)
plt.plot(date, closePrice)
plt.plot(date, highest)
plt.plot(date, lowest)

# %% [markdown]
# ## Using Transformer Model to Capture whole tems movement

# %% [markdown]
# pos = position
# k = key
# d = dimension
#
# position -> choosing one day of stock price (should be latest day)
# k =
